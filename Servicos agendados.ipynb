# %%
import requests
import pandas as pd

# %% [markdown]
# # Login

# %%
url = "http://127.0.0.1:9000/api/".replace("\\","/")

# %%
username="zeladorx@zeladorx.com.br"
password="Amendoin123"

body = {
    "username":username,
    "password":password
}

# %%
response = requests.post("http://127.0.0.1:9000/api/login", body)

# %%
response.json()
# Out:
# {'token': '171db50f8cc06dae8ae7338bdc5048ddc97f6784',
#  'id_random': '6uW6BnjPFHyd',
#  'user_id': 1,
#  'username': 'zeladorx',
#  'email': 'zeladorx@zeladorx.com.br',
#  'is_superuser': True}

# %% [markdown]
# # Auth

# %%
headers = {
    "Authorization": f"Token {response.json()['token']}"
}

# %% [markdown]
# # Servicos agendados

# %%
# retorna todas as servicos cadastradas, que o usário tem permissão para visualizar
# codigo de permissão necessário --> 322: Pode visualizar serviços agendados

response = requests.get("http://127.0.0.1:9000/api/servicos/agendados/ListServicoJardinagemAgendadoAnotados/", headers=headers)
response.json()['results']
df = pd.DataFrame(response.json()['results'])
display(df)
# Out:
#    id     id_random DescricaoDoServico               DataDeInicio  \
# 0   9  Uzf7OCm1c4yg             steste  2025-08-16T23:19:00-03:00
# 1  10  P1n687HSearU             steste  2025-08-16T23:19:00-03:00
#
#              DataDeConclusao TipoServico  Areas ServicosEscalados  \
# 0  2025-08-17T04:19:00-03:00     Regular     12               [1]
# 1  2025-08-18T23:19:00-03:00     Regular     12            [1, 4]
#
#   ColaboradoresEscalados foto_solicitacao foto_entrega  dias_diferenca  \
# 0                    [6]             None         None               0
# 1                    [6]             None         None               0
#
#   novo_status
# 0     Próximo
# 1     Próximo

# %% [markdown]
# ## Criar nova servicos agendados

# %%
## As colunas, Areas, ServicosEscalados, ColaboradoresEscalados são chaves estrangeiras e precisam estar devidamente configuradas
## sendo obriagatorios

# %%
# lista de areas dispniveis para solitarem acesso
response = requests.get("http://127.0.0.1:9000/api/areas/ListAreasJardinagemFromFoms/", headers=headers)
response.json()['results']
df = pd.DataFrame(response.json()['results'])
display(df)
print()

# lista de areas dispniveis para solitarem acesso
response = requests.get("http://127.0.0.1:9000/api/catalogo_de_servicos/ListCatalogodeServicoJardinagemFromForms/", headers=headers)
response.json()['results']
df = pd.DataFrame(response.json()['results'])
display(df)
print()

# lista de colaboradores que podem ser adiconados
response = requests.get("http://127.0.0.1:9000/api/gerentes/ListGerenteJardinagemFromForms/", headers=headers)
response.json()['results']
df = pd.DataFrame(response.json()['results'])
display(df)
print()
# Out:
#    id     id_random              nome  dimensao  Terreno  vegetacao  servico  \
# 0   1  fv606QhhZNxf   ARea post man 1    1000.0        3          1        1
# 1   2  hrDNIOMD846d     ARea post man    1567.0        1          1        1
# 2   3  TMfwGyydy4TO   ARea post man 1    1000.0        1          1        1
# 3   4  6PZrwKucJ8DY   ARea post man 1    1000.0        1          1        1
# 4   6  dqqj32YqQQet   ARea post man 1    1000.0        1          1        1
# 5   7  RI9y34a49pds   ARea post man 1    1000.0        1          1        1
# 6   8  or5DdMufYyKX  testes if delete     874.0        2          5        2
#
#    localidade  foto periodicidade      status
# 0           4  None     Semestral  Mobilizado
# 1           1  None     Semestral  Mobilizado
# 2           1  None        Mensal  Mobilizado
# 3           1  None     Semestral  Mobilizado
# 4           4  None     Semestral  Mobilizado
# 5           4  None     Semestral  Mobilizado
# 6           4  None        Mensal  Mobilizado
#    id     id_random                       nome  EmpresaSecundaria      status
# 0   1  gelP0OZifsu1       Markos Alves Pereira                  1  Mobilizado
# 1   2  MLrCUtPzNxW8  vegeta jupyter atualizada                  9  Mobilizado
# 2   3  iBjLYt9CzNW5             catalogo teste                  9  Mobilizado
#    id     id_random             username                              email  \
# 0   5  K4341ZakSLwN               markos  datascienceanalytics191@gmail.com
# 1   6  YbJATdW4PFrA  teseteconfigpostman      teseteconfigpostman@email.com
#
#   empresasecundaria  is_superuser      status
# 0               [6]         False  Mobilizado
# 1               [6]         False  Mobilizado

# %%
# exemplo de envio de boby para criar uma no servico
body = {
    'Areas': 1, # vem de api/areas/ListAreasJardinagemFromFoms/
    'TipoServico': "Regular", #opcoes validas Regular, Extra, Automático
    'DescricaoDoServico':  "teste jupyter agndamento", 
    'ServicosEscalados': 1, # vem de api/catalogo_de_servicos/ListCatalogodeServicoJardinagemFromForms/
    'DataDeInicio': "2025-08-08T13:57:00-03:00", #agendamento para 11/08/2025 13:57 -- > ajusta o fuso horario :00-03:00
    'DataDeConclusao': "2025-08-11T19:57:00-03:00",
    'ColaboradoresEscalados': 5, # vem de api/gerentes/ListGerenteJardinagemFromForms/
    'foto_solicitacao': "", # file com uma foto da area no momento da solicitação
    'foto_entrega': "", # file com uma foto da area no momento da entrega
}

# %%
# codigo de permissão necessário --> 320: Pode agendar novos serviços
response = requests.post("http://127.0.0.1:9000/api/servicos/agendados/CreateServicosJardinagem/", body, headers=headers)
response.json()
# Out:
# {'success': True,
#  'message': 'ServicoJardinagemAgendado criado com sucesso.',
#  'data': {'id': 8,
#   'id_random': 'vvEIdgA4VhLz',
#   'Areas': 1,
#   'TipoServico': 'Regular',
#   'DescricaoDoServico': 'teste jupyter agndamento',
#   'ServicosEscalados': [1],
#   'DataDeInicio': '2025-08-08T13:57:00-03:00',
#   'DataDeConclusao': '2025-08-11T19:57:00-03:00',
#   'ColaboradoresEscalados': [5],
#   'foto_solicitacao': None,
#   'foto_entrega': None}}

# %% [markdown]
# # Detalhes da serviço agendado

# %%
# enviar o id random do servico que quer se avaliar
# codigo de permissao 322: Pode visualizar serviços agendados
response = requests.get("http://127.0.0.1:9000/api/servicos/agendados/ServicosJardinagemDetail/vvEIdgA4VhLz/", headers=headers)
response.json()
# Out:
# {'id': 8,
#  'id_random': 'vvEIdgA4VhLz',
#  'Areas': 1,
#  'TipoServico': 'Regular',
#  'DescricaoDoServico': 'teste jupyter agndamento',
#  'ServicosEscalados': [1],
#  'DataDeInicio': '2025-08-08T13:57:00-03:00',
#  'DataDeConclusao': '2025-08-11T19:57:00-03:00',
#  'ColaboradoresEscalados': [5],
#  'foto_solicitacao': None,
#  'foto_entrega': None}

# %% [markdown]
# # atualizar servico agendado

# %%
# as chaves body da atualização é exatamente igual o body da criacao
# atualiando a periodicidade para bimestral

body = {
    'Areas': 1, # vem de api/areas/ListAreasJardinagemFromFoms/
    'TipoServico': "Regular", #opcoes validas Regular, Extra, Automático
    'DescricaoDoServico':  "teste jupyter agndamento", 
    'ServicosEscalados': 1, # vem de api/catalogo_de_servicos/ListCatalogodeServicoJardinagemFromForms/
    'DataDeInicio': "2025-08-08T13:57:00-03:00", #agendamento para 11/08/2025 13:57 -- > ajusta o fuso horario :00-03:00
    'DataDeConclusao': "2025-08-11T19:57:00-03:00",
    'ColaboradoresEscalados': 5, # vem de api/gerentes/ListGerenteJardinagemFromForms/
    'foto_solicitacao': "", # file com uma foto da area no momento da solicitação
    'foto_entrega': "", # file com uma foto da area no momento da entrega
}

# %%
# essa rota recebe o id random da servico como parametro de url, consultar em api/servicos/agendados/ServicosJardinagemUpdate/id_random/
# atualizando a área criada anteriormente, obeserve o id_random
# codigo de permissão necessário --> 321: Pode editar serviços agendados

response = requests.put("http://127.0.0.1:9000/api/servicos/agendados/ServicosJardinagemUpdate/vvEIdgA4VhLz/", body, headers=headers)
response.json()
# Out:
# {'success': True,
#  'message': 'ServicoJardinagemAgendado atualizado com sucesso.',
#  'data': {'id': 8,
#   'id_random': 'vvEIdgA4VhLz',
#   'Areas': 1,
#   'TipoServico': 'Regular',
#   'DescricaoDoServico': 'teste jupyter agndamento',
#   'ServicosEscalados': [1],
#   'DataDeInicio': '2025-08-09T13:57:00-03:00',
#   'DataDeConclusao': '2025-08-11T19:57:00-03:00',
#   'ColaboradoresEscalados': [5],
#   'foto_solicitacao': None,
#   'foto_entrega': None}}

# %% [markdown]
# # Alterar Status do servico

# %%
# essa rota recebe o id random da servico como parametro de url, consultar em servicos/agendados/ListServicoJardinagemAgendadoAnotados/
# atualizando a servico criada anteriormente, obeserve o id_random
# codigo de permissão necessário --> 
# 320: Pode agendar novos serviços para Agendado (Desmobilizado) ou
# 361: Pode acompanhar serviços agendados para si próprio ou 324: Pode acompanhar serviços agendados para Em andamento (Mobilizado)
# 326: Pode concluir serviços em andamento para Concluido
# 328: Pode cancelar serviços agendados para Cancelado


STATUS_PERMISSION_MAP = {
    'Agendado': ['320: Pode agendar novos serviços'],
    'Em andamento': [
        '361: Pode acompanhar serviços agendados para si próprio',
        '324: Pode acompanhar serviços agendados'
    ],
    'Concluido': ['326: Pode concluir serviços em andamento'],
    'Cancelado': ['328: Pode cancelar serviços agendados']
}


body = {
    'status': 'Agendado', # pde ser Agendado, Em andamento, Concluido, Cancelado
}

response = requests.put("http://127.0.0.1:9000/api/servicos/agendados/AlterStatusServicoJardinagem/vvEIdgA4VhLz/", body, headers=headers)
response.json()
# Out:
# {'detail': "Status alterado com sucesso para 'Cancelado'."}

# %% [markdown]
# # Se deletar Serviço

# %%
# essa rota recebe o id random da servico como parametro de url, consultar em api/areas/ListAreasJardinagem/
# codigo de permissão necessário --> 323: Pode excluir serviços agendados

response = requests.get("http://127.0.0.1:9000/api/servicos/agendados/IfDeleteServicoAgendadoJardinagem/vvEIdgA4VhLz/", headers=headers)
response.json()
# Out:
# {'detail': 'Objeto não encontrado.'}

# %% [markdown]
# # Deleção de serviços

# %%
# essa rota recebe o id random da servico como parametro de url, consultar em api/areas/ListAreasJardinagem/
# codigo de permissão necessário --> 323: Pode excluir serviços agendados

response = requests.delete("http://127.0.0.1:9000/api/servicos/agendados/DeleteServicoAgendadoJardinagem/Uzf7OCm1c4yg/", headers=headers)
response.json()
# Out:
# {'detail': "ServicoJardinagemAgendado 'steste -- 17/08/2025 02:19 -- teseteconfigpostman ' foi deletado com sucesso."}
