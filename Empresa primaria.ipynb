# %%
import requests
import pandas as pd

# %% [markdown]
# # Login

# %%
url = "http://127.0.0.1:9000/api/".replace("\\","/")

# %%
username="testeuser@zeladorx.com.br"
password="TESte2026&"

body = {
    "username":username,
    "password":password
}

# %%
response = requests.post("http://127.0.0.1:9000/api/login", body)

# %%
response.json()
# Out:
# {'token': '171db50f8cc06dae8ae7338bdc5048ddc97f6784',
#  'id_random': '6uW6BnjPFHyd',
#  'user_id': 1,
#  'username': 'zeladorx',
#  'email': 'zeladorx@zeladorx.com.br',
#  'is_superuser': True}

# %% [markdown]
# # Auth

# %%
headers = {
    "Authorization": f"Token {response.json()['token']}"
}

# %% [markdown]
# # Ecossistema

# %%
# endpoint retorna os dados referente ao ecossistema contratado junto ao ZeladorX, no pode ser editado VIA API
response = requests.get("http://127.0.0.1:9000/api/zeladorx/EmpresaPrimaria/", headers=headers)

# %%
response.json()
# Out:
# {'empresa_primaria': [{'id': 1,
#    'id_random': 'hKHYKomnXjNs',
#    'nome': 'ZeladorX',
#    'N_unidades': 5,
#    'status': 'Mobilizado',
#    'setor': [1, 2]}]}

# %% [markdown]
# # Macro servicos habilitados

# %%
# retonra os macro servicos disponiveis para o usuario
response = requests.get("http://127.0.0.1:9000/api/zeladorx/MyMacroServices/", headers=headers)

# %%
response.json()
# Out:
# {'macro_servicos_habilitados': [{'id': 1, 'setor': 'Jardinagem'},
#   {'id': 2, 'setor': 'Limpeza predial'}]}
