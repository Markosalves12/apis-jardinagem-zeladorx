# %%
import requests
import pandas as pd

# %% [markdown]
# # Login

# %%
url = "http://127.0.0.1:9000/api/".replace("\\","/")

# %%
username="testeuser@zeladorx.com.br"
password="TESte2026&"

body = {
    "username":username,
    "password":password
}

# %%
response = requests.post("http://127.0.0.1:9000/api/login", body)

# %%
response.json()
# Out:
# {'token': '171db50f8cc06dae8ae7338bdc5048ddc97f6784',
#  'id_random': '6uW6BnjPFHyd',
#  'user_id': 1,
#  'username': 'zeladorx',
#  'email': 'zeladorx@zeladorx.com.br',
#  'is_superuser': True}

# %% [markdown]
# # Auth

# %%
headers = {
    "Authorization": f"Token {response.json()['token']}"
}

# %% [markdown]
# # Codigos de permissão disponiveis para uso

# %% [markdown]
# # lista de permissoes de jardinagem disponiveis

# %%
# os endpointe desse software estao elencados em api/permissions/ListPermissionsJardinagem/
# esses codigos sao uteis para o desnevolvevodor desenvover aplicacoes
response = requests.get("http://127.0.0.1:9000/api/permissions/ListPermissionsJardinagem/", headers=headers)
df = pd.DataFrame(response.json())
display(df)
# Out:
#     id       id_random                                        Permissions
# 0    1    qbw32fdjLXZz          250: Pode criar novas áreas de jardinagem
# 1    2    IBP1Sf5hlYav               251: Pode editar áreas de jardinagem
# 2    3    xBYplH0hiAZq           252: Pode visualizar áreas de jardinagem
# 3    4    WiKkjCB6PsUT              253: Pode excluir áreas de jardinagem
# 4    5    ng2xsJGI2sNl         254: Pode desmobilizar áreas de jardinagem
# ..  ..             ...                                                ...
# 62  63   0BPZ3zUDHSKwr                        401: Pode editar checklists
# 63  64    Fvma3vEWNoUp                    402: Pode visualizar checklists
# 64  65  00VjcQKoiJuvqg                       403: Pode excluir checklists
# 65  66    cnBvvZQKQ8WH  410: Pode editar o recebimento de notificações...
# 66  67    UvPFd6a1eT40  411: Pode editar o recebimento de notificações...
#
# [67 rows x 3 columns]

# %%
n
