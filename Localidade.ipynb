# %%
import requests
import pandas as pd

# %% [markdown]
# # Login

# %%
url = "http://127.0.0.1:9000/api/".replace("\\","/")

# %%
username="testeuser@zeladorx.com.br"
password="TESte2026&"

body = {
    "username":username,
    "password":password
}

# %%
response = requests.post("http://127.0.0.1:9000/api/login", body)

# %%
response.json()
# Out:
# {'token': '171db50f8cc06dae8ae7338bdc5048ddc97f6784',
#  'id_random': '6uW6BnjPFHyd',
#  'user_id': 1,
#  'username': 'zeladorx',
#  'email': 'zeladorx@zeladorx.com.br',
#  'is_superuser': True}

# %% [markdown]
# # Auth

# %%
headers = {
    "Authorization": f"Token {response.json()['token']}"
}

# %% [markdown]
# # localidades

# %%
# retorna todas as localidades cadastradas, que o usário tem permissão para visualizar
# codigo de permissão necessário --> 292: Pode visualizar localidades
response = requests.get("http://127.0.0.1:9000/api/localidades/ListLocalidadeJardinagem/", headers=headers)
response.json()['results']
df = pd.DataFrame(response.json()['results'])
display(df)
# Out:
#    id     id_random                                               nome  \
# 0   1  5aL9y6XsNngG                               Markos Alves Pereira
# 1   2  6qOmeTCSILRn  ççaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...
# 2   4  ge0FzCRcrraF                                       space markos
# 3   5  nd3afJ2NeVWu                   localidade do jupyter atualziado
#
#    lat_med  long_med  unidade         status
# 0    31.15     31.15        1     Mobilizado
# 1   121.00    123.00        1     Mobilizado
# 2   121.00    123.00        2     Mobilizado
# 3    14.56      8.64        3  Desmobilizado

# %% [markdown]
# ## Criar nova Localidades

# %%
## As colunas, unidade são chaves estrangeiras e precisam estar devidamente configuradas
## sendo obriagatorios

# %%
# Lista de unidades que podem ser enviados pelo usuario logado
# nao precisa de permissao
response = requests.get("http://127.0.0.1:9000/api/unidades/ListUnidadeFromForms/", headers=headers)
response.json()['results']
df = pd.DataFrame(response.json()['results'])
display(df)
# Out:
#    id     id_random                                               nome  \
# 0   1  hDVjIq1JYBOZ                                    unidade jupyter
# 1   2  IT2RffZXUtvV           aLKFJKBWFJBSDJCKBSAJCBSKJDBCKSDBJCKBSDJK
# 2   3  75X3nHLHlXKc  aLKFJKBWFJBSDJCKBSAJCBSKJDBCKSDBJCKBSDJKssssss...
# 3   5  3epdU0gHQDg3                                    PosatmanuNIdade
# 4   6  neN812qtAhzQ                                    unidade jupyter
#
#                                   linkmapajardinagem  \
# 0
# 1  https://www.google.com/maps/d/u/0/embed?mid=1D...
# 2  https://www.google.com/maps/d/u/0/embed?mid=1D...
# 3                                               None
# 4
#
#                              linkmapalimnpezapredial empresasecundaria  \
# 0                                                                  [6]
# 1  https://www.google.com/maps/d/u/0/embed?mid=1D...               [2]
# 2  https://www.google.com/maps/d/u/0/embed?mid=1D...               [1]
# ...

# %%
# exemplo de envio de boby para criar uma nova localidade
body = {
    'nome': "localidade do jupyter", 
    'lat_med': 14.56,
    'long_med': 8.64, 
    'unidade': 3, # vem de api/unidades/ListUnidadeFromForms/
}

response = requests.post("http://127.0.0.1:9000/api/localidades/CreateLocalidadeJardins/", body, headers=headers)
response.json()
# Out:
# {'success': True,
#  'message': 'LocalidadeJardiangem criado com sucesso.',
#  'data': {'id': 5,
#   'id_random': 'nd3afJ2NeVWu',
#   'nome': 'localidade do jupyter',
#   'lat_med': 14.56,
#   'long_med': 8.64,
#   'unidade': 3,
#   'status': 'Mobilizado'}}

# %% [markdown]
# # Detalhes da localidade

# %%
# essa rota recebe o id random da localidade como parametro de url, consultar em api/localidades/ListLocalidadeJardinagem/
# detalhes da loalidade riada anteriormente, obeserve o id_random
# http://127.0.0.1:9000/api/localidades/LocalidadeJardinagemDetail/id_random/
# codigo de permissão necessário -->292: Pode visualizar localidades
response = requests.get("http://127.0.0.1:9000/api/localidades/LocalidadeJardinagemDetail/nd3afJ2NeVWu/", headers=headers)
response.json()
# Out:
# {'id': 5,
#  'id_random': 'nd3afJ2NeVWu',
#  'nome': 'localidade do jupyter atualziado',
#  'lat_med': 14.56,
#  'long_med': 8.64,
#  'unidade': 3,
#  'status': 'Desmobilizado'}

# %% [markdown]
# # atualizar Localidade

# %%
# as chaves body da atualização é exatamente igual o body da criacao
# atualiando a nome para localidade do jupyter atualziado
body = {
    'nome': "localidade do jupyter atualziado", 
    'lat_med': 14.56,
    'long_med': 8.64, 
    'unidade': 3, # unidade disponivel em ListUnidadeFromForms
}

# %%
# essa rota recebe o id random da localidade como parametro de url, consultar em api/areas/ListLocalidadeJardinagem/
# atualizando a localidade criada anteriormente, obeserve o id_random
# codigo de permissão necessário --> 291: Pode editar localidades
response = requests.put("http://127.0.0.1:9000/api/localidades/LocalidadeJardinagemUpdate/nd3afJ2NeVWu/", body, headers=headers)
response.json()
# Out:
# {'success': True,
#  'message': 'LocalidadeJardiangem atualizado com sucesso.',
#  'data': {'id': 5,
#   'id_random': 'nd3afJ2NeVWu',
#   'nome': 'localidade do jupyter atualziado',
#   'lat_med': 14.56,
#   'long_med': 8.64,
#   'unidade': 3,
#   'status': 'Mobilizado'}}

# %% [markdown]
# # Alterar Status da localidade

# %%
# essa rota recebe o id random da localidade como parametro de url, consultar em api/localidades/ListLocalidadeJardinagem/
# atualizando a localidade criada anteriormente, obeserve o id_random
# codigo de permissão necessário --> 
# 294: Pode desmobilizar localidades para demosbilizar (Desmobilizado) ou
# 295: Pode reabilitar localidades para reabilitar (Mobilizado)

body = {
    'status': 'Desmobilizado'
}

response = requests.put("http://127.0.0.1:9000/api/localidades/LocalidadeJardinagemAlterStatus/nd3afJ2NeVWu/", body, headers=headers)
response.json()
# Out:
# {'success': True,
#  'message': "Status da localidade de jardinagem atualizado com sucesso. Novo status: 'Desmobilizado'.",
#  'data': {'id_random': 'nd3afJ2NeVWu', 'status': 'Desmobilizado'}}

# %% [markdown]
# # Se deletar localidade

# %%
# essa rota recebe o id random da localidade como parametro de url, consultar em api/localidades/ListLocalidadeJardinagem/
# codigo de permissão necessário --> 293: Pode excluir localidades
response = requests.get("http://127.0.0.1:9000/api/localidades/IfDeleteLocalidadeJardinagem/nd3afJ2NeVWu/", headers=headers)
response.json()
# Out:
# {'objeto_principal': 'localidade do jupyter atualziado -- aLKFJKBWFJBSDJCKBSAJCBSKJDBCKSDBJCKBSDJKssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss',
#  'resumo': {'LocalidadeJardiangem': 1},
#  'objetos_em_cascata': ['- localidade do jupyter atualziado -- aLKFJKBWFJBSDJCKBSAJCBSKJDBCKSDBJCKBSDJKssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss']}

# %% [markdown]
# # Deleção da localidade

# %%
# essa rota recebe o id random da localidade como parametro de url, consultar em api/localidades/ListLocalidadeJardinagem/
# codigo de permissão necessário --> 293: Pode excluir localidades
response = requests.delete("http://127.0.0.1:9000/api/localidades/DeleteLocalidadeJardinagem/nd3afJ2NeVWu/", headers=headers)
response.json()
# Out:
# {'detail': "LocalidadeJardiangem 'localidade do jupyter atualziado -- aLKFJKBWFJBSDJCKBSAJCBSKJDBCKSDBJCKBSDJKssssssssssssssssssssssssssssssssssssssssssssssssssssssssssss' foi deletado com sucesso."}

# %% [markdown]
# # Localidades disponiveis para os formularios

# %%
# localidade desmobilizadas da operação nao podem receber servicos, consultar no manual de intruções
# não precisa de permissão
response = requests.get("http://127.0.0.1:9000/api/localidades/ListLocalidadeJardinagemFromForms/", headers=headers)
response.json()['results']
df = pd.DataFrame(response.json()['results'])
display(df)
# Out:
#    id     id_random                                               nome  \
# 0   1  5aL9y6XsNngG                               Markos Alves Pereira
# 1   2  6qOmeTCSILRn  ççaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...
#
#    lat_med  long_med  unidade      status
# 0    31.15     31.15        1  Mobilizado
# 1   121.00    123.00        1  Mobilizado
